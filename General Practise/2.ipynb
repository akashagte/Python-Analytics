# %%
# %matplotlib inline
from __future__ import print_function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
incomes=np.random.normal(100.0,50.0,10000)
plt.hist(incomes,50)
plt.show()

# %%
incomes.std()
# Out:
# 49.984829430905883

# %%
incomes.var()
# Out:
# 2498.4831732367552

# %%
values=np.random.uniform(-10.0,10.0,10000)
plt.hist(values,50)
plt.show()

# %%
from scipy.stats import norm
x=np.arange(-3,3,0.001)
plt.plot(x,norm.pdf(x))

# %%
from scipy.stats import expon, binom
x=np.arange(0,10,0.001)
plt.plot(x,expon.pdf(x))

# %%
n,p=10,0.5
x=np.arange(0,10,0.001)
plt.plot(x,binom.pmf(x,n,p))

# %%
from scipy.stats import poisson
mu=500
x=np.arange(400,600,0.5)
plt.plot(x,poisson.pmf(x,mu))

# %%
vals=np.random.normal(0,0.5,10000)
plt.hist(vals,50)
plt.show()

# %%
np.percentile(vals,90)
# Out:
# 0.63058321010987672

# %%
np.percentile(vals,20)
# Out:
# -0.42501206387755819

# %%
np.mean(vals)
# Out:
# -0.0023978888588304858

# %%
np.var(vals)
# Out:
# 0.25130733283057544

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# 0.01731171161479735

# %%
sp.kurtosis(vals)
# Out:
# 0.06103713060263116

# %%
x=np.arange(-3,3,0.001)

# %%
from scipy.stats import norm

# %%
plt.plot(x,norm.pdf(x),'b--')
plt.plot(x,norm.pdf(x,1.0,0.5),'r-')
plt.grid()
plt.xlim(-4,4)
plt.ylim(0.0,1.0)
plt.xlabel('Akash')
plt.ylabel('Akanksha')
plt.legend(['Lol','Max'],loc=4)
plt.savefig('C:/Users/Akash Agte/Downloads/Learning/Python/Practise2/MyPlot.png',format='png')

# %%
plt.xkcd
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([-30, 10])

data = np.ones(100)
data[70:] -= np.arange(30)

plt.annotate(
    'THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED',
    xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

plt.plot(data)

plt.xlabel('time')
plt.ylabel('my overall health')

# %%
plt.rcdefaults()
values=[12,38,24,11,10,5]
labels=['m','n','o','p','g','t']
explode=[0,0,0,0,0.1,0]
plt.pie(values,labels=labels,explode=explode)
plt.show()
